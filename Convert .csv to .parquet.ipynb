# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\vinicius.oliveira\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\vinicius.oliveira\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
import pyarrow

# %%
csv_file = r'C:/Users/vinicius.oliveira/Desktop/CSV.csv'

# %%
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#   Name;Type;Max Lenght;;Name;Type;Max Lenght;;Name;Type;Size;Source;Description
# 0  carga_timestamp;timestamp;29;;carga_timestamp;...
# 1  faturamentoclientecpfcnpj;varchar;254;;cliente...
# 2  faturamentoclienteprincipalcpfcnpj;varchar;254...
# 3  faturamentoano;int2;6;;ano;int2;6;;faturamento...
# 4  faturamentocfop;varchar;258;;cfop;varchar;30;;...

# %%
parquet_out = r'C:/Users/vinicius.oliveira/Desktop/CSV.parquet'

# %%
output = df.to_parquet(parquet_out, index = False)
